# %% [markdown]
# # CA4015 Application Domains Assignments
# For this assignment, I will be analysis my personal data that I have gathered from SleepScore, Fitbit and CBT Thought Diary

# %%
import numpy as np
import pandas as pd
import os

# %%
pwd
# Out:
# 'C:\\Users\\Diarmuid\\Documents\\dcu\\final-year\\ca4016_application_domains\\ca4016_application_domains_2\\notebooks'

# %%
fitbit_path = '../data/fitbit_data.csv'

# %%
fitbit_df = pd.read_csv(fitbit_path)

# %%
fitbit_df.head()
# Out:
#          Body Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0        Date     Weight        BMI        Fat        NaN        NaN
# 1  01/10/2022      72.98      23.56          0        NaN        NaN
# 2  02/10/2022      72.97      23.56          0        NaN        NaN
# 3  03/10/2022      72.95      23.55          0        NaN        NaN
# 4  04/10/2022      72.94      23.55          0        NaN        NaN
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN

# %%
activities_index = fitbit_df.Body[fitbit_df.Body == 'Activities'].index[0]
# Out:
# 27

# %%
raw_df = pd.read_csv(fitbit_path, names=list(range(10)))

# %%
raw_df
# Out:
#                      0                  1      2    3    4    5    6    7  \
# 0                 Body                NaN    NaN  NaN  NaN  NaN  NaN  NaN
# 1                 Date             Weight    BMI  Fat  NaN  NaN  NaN  NaN
# 2           01/10/2022              72.98  23.56    0  NaN  NaN  NaN  NaN
# 3           02/10/2022              72.97  23.56    0  NaN  NaN  NaN  NaN
# 4           03/10/2022              72.95  23.55    0  NaN  NaN  NaN  NaN
# ..                 ...                ...    ...  ...  ...  ...  ...  ...
# 70  2022-10-05 12:35AM  2022-10-05 7:15AM    352   48   20  400   74  208
# 71  2022-10-03 11:09PM  2022-10-04 6:35AM    382   64   28  446   53  247
# 72  2022-10-02 10:45PM  2022-10-03 6:52AM    426   61   28  487  104  264
# 73  2022-10-01 10:33PM  2022-10-02 7:21AM    437   91   32  528   84  297
# 74  2022-09-30 11:11PM  2022-10-01 7:32AM    447   54   33  501   80  277
#
#       8    9
# 0   NaN  NaN
# 1   NaN  NaN
# 2   NaN  NaN
# 3   NaN  NaN
# 4   NaN  NaN
# ..  ...  ...
# 70   70  NaN
# 71   82  NaN
# 72   58  NaN
# 73   56  NaN
# 74   90  NaN
#
# [75 rows x 10 columns]

# %%
int(np.where(raw_df[0] == category)[0] + 1)
# Out:
# 29

# %%
target_csv=fitbit_path
category='Activities'
raw_df = pd.read_csv(target_csv,names = list(range(10)), skip_blank_lines = False)

# %%
    #"start" denotes the index where the data in the desired category begins
start = int(np.where(raw_df[0] == category)[0] + 1)

    #"blank_separators" is a list of indices where the first column value is null, meaning the end of a category
blank_separators = np.where(raw_df[0][start:].isnull())[0]

# %%
blank_separators
# Out:
# array([26], dtype=int64)

# %%
stop = blank_separators[0] - 1 if len(blank_separators) > 0 else len(raw_df) - 1

# %%
stop
# Out:
# 74

# %%
def get_df(target_csv, category):
        #raw_df is a DataFrame that contains all the messy data in the original .csv file
    raw_df = pd.read_csv(target_csv,names = list(range(10)), skip_blank_lines = False)
    
        #"start" denotes the index where the data in the desired category begins
    start = int(np.where(raw_df[0] == category)[0] + 1)
    
        #"blank_separators" is a list of indices where the first column value is null, meaning the end of a category
    blank_separators = np.where(raw_df[0][start:].isnull())[0]
    
        #"stop" finds the first value in this list comprehension of "blank_separators" that comes after the "start" index
    stop = (blank_separators[0] - 1) if len(blank_separators) > 0 else (len(raw_df) - 1)
    return(pd.read_csv(target_csv, skiprows = start, nrows = stop-start))

# %%
activities_df = get_df(fitbit_path, 'Activities')
sleep_df = get_df(fitbit_path, 'Sleep')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [112], line 1
# ----> 1 activities_df = get_df(fitbit_path, 'Activities')
#       2 sleep_df = get_df(fitbit_path, 'Sleep')
#
# Cell In [111], line 13, in get_df(target_csv, category)
#      11     #"stop" finds the first value in this list comprehension of "blank_separators" that comes after the "start" index
#      12 stop = (blank_separators[0] - 1) if len(blank_separators) > 0 else (len(raw_df) - 1)
# ---> 13 return(pd.read_csv(target_csv, skiprows = start, nrows = stop-start))
#
# File ~\anaconda3\envs\ca4016_application_domains\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\ca4016_application_domains\lib\site-packages\pandas\io\parsers\readers.py:678, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     663 kwds_defaults = _refine_defaults_read(
#     664     dialect,
#     665     delimiter,
#    (...)
#     674     defaults={"delimiter": ","},
#     675 )
#     676 kwds.update(kwds_defaults)
# --> 678 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\envs\ca4016_application_domains\lib\site-packages\pandas\io\parsers\readers.py:581, in _read(filepath_or_buffer, kwds)
#     578     return parser
#     580 with parser:
# --> 581     return parser.read(nrows)
#
# File ~\anaconda3\envs\ca4016_application_domains\lib\site-packages\pandas\io\parsers\readers.py:1251, in TextFileReader.read(self, nrows)
#    1249         raise
#    1250 else:
# -> 1251     nrows = validate_integer("nrows", nrows)
#    1252     try:
#    1253         index, columns, col_dict = self._engine.read(nrows)
#
# File ~\anaconda3\envs\ca4016_application_domains\lib\site-packages\pandas\io\parsers\readers.py:510, in validate_integer(name, val, min_val)
#     508         val = int(val)
#     509     elif not (is_integer(val) and val >= min_val):
# --> 510         raise ValueError(msg)
#     512 return val
#
# ValueError: 'nrows' must be an integer >=0

# %%
activities_df
# Out:
#           Date Calories Burned   Steps  Distance  Floors Minutes Sedentary  \
# 0   01/10/2022           3,068   9,944      7.25      19               550
# 1   02/10/2022           2,979  10,925      8.01      19               577
# 2   03/10/2022           3,496  12,709      9.26      12               523
# 3   04/10/2022           2,769   9,808      7.17      17               752
# 4   05/10/2022           3,146  12,934      9.44      16               729
# 5   06/10/2022           1,890   1,873      1.48       5               879
# 6   07/10/2022           1,729       0      0.00       0             1,440
# 7   08/10/2022           1,729       0      0.00       0             1,440
# 8   09/10/2022           1,729       0      0.00       0             1,440
# 9   10/10/2022           1,729       0      0.00       0             1,440
# 10  11/10/2022           1,776     184      0.13       0             1,427
# 11  12/10/2022           3,359  14,841     10.83      22               562
# 12  13/10/2022           2,885  10,836      8.06      10               646
# 13  14/10/2022           3,159  12,300      8.97      17             1,116
# 14  15/10/2022           3,615  24,424     17.92      47               597
# 15  16/10/2022           2,641   6,239      4.73       8               787
# 16  17/10/2022           2,935   9,918      7.34      17               780
# 17  18/10/2022           3,082  13,818     10.45      15             1,101
# 18  19/10/2022           2,813  10,181      7.63      18             1,198
# 19  20/10/2022           3,331  15,806     11.63      18               620
# 20  21/10/2022           3,369  15,047     11.04      22               618
# 21  22/10/2022           2,628   7,800      5.69      12               707
# 22  23/10/2022           2,403   7,193      5.25       6             1,260
# 23  24/10/2022           3,978  23,288     16.97      21               417
# 24  25/10/2022           1,420   3,675      2.68       6               414
#
#     Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      379                      4                    6
# 1                      292                     17                   26
# 2                      390                     28                   12
# 3                      209                     21                   12
# 4                      246                     28                   37
# 5                       40                      0                    0
# 6                        0                      0                    0
# 7                        0                      0                    0
# 8                        0                      0                    0
# 9                        0                      0                    0
# 10                      13                      0                    0
# 11                     265                     42                   48
# 12                     273                      9                    9
# 13                     246                     38                   40
# 14                     291                     45                  104
# 15                     169                     11                   25
# 16                     108                     35                   65
# 17                     312                      6                   21
# 18                     160                     43                   39
# 19                     327                     14                   36
# 20                     350                     21                   33
# 21                     301                      9                    0
# 22                     137                     25                   18
# 23                     376                     30                   94
# 24                      65                      0                    0
#
#    Activity Calories
# 0              1,660
# 1              1,504
# 2              2,143
# 3              1,242
# 4              1,632
# 5                195
# 6                  0
# 7                  0
# 8                  0
# 9                  0
# 10                45
# 11             1,934
# 12             1,357
# 13             1,690
# 14             2,322
# 15             1,029
# 16             1,379
# 17             1,627
# 18             1,281
# 19             1,885
# 20             1,983
# 21             1,198
# 22               859
# 23             2,753
# 24               358
